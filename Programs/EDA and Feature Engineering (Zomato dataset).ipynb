# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Prabal Kuinkel\Desktop\Data Analyst\PYTHON JUPYTERNOOTBOOK\Data sets and notes\Zomato data set\zomato.csv",encoding='latin-1')

# %%
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# df.info()

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # In data analysis what all things we do
#
# 1. Missing values
# 2. Explore about the numerical Variables
# 3. Explore about categorical Variables
# 4. Finding Relationship between Features

# %%
#1. Missing Values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Identifying the Columns that has null values:
null_columns=[col for col in df.columns if df[col].isnull().sum()>0]
print(null_columns)
# Out:
# ['Cuisines']

# %%
df.isnull().sum()/df.shape[0] * 100
# Out:
# Restaurant ID           0.000000
# Restaurant Name         0.000000
# Country Code            0.000000
# City                    0.000000
# Address                 0.000000
# Locality                0.000000
# Locality Verbose        0.000000
# Longitude               0.000000
# Latitude                0.000000
# Cuisines                0.094231
# Average Cost for two    0.000000
# Currency                0.000000
# Has Table booking       0.000000
# Has Online delivery     0.000000
# Is delivering now       0.000000
# Switch to order menu    0.000000
# Price range             0.000000
# Aggregate rating        0.000000
# Rating color            0.000000
# Rating text             0.000000
# Votes                   0.000000
# dtype: float64

# %%
#Heat map to visualze the null values in each columns
#Here nothing is visible because the number of null values present in Cuisines is very less(only 0.094231 %)
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_c=pd.read_excel(r"C:\Users\Prabal Kuinkel\Desktop\Data Analyst\PYTHON JUPYTERNOOTBOOK\Data sets and notes\Zomato data set\Country-Code.xlsx")
df_c.head(15)
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_c.shape
# Out:
# (15, 2)

# %%
# Merging the df (zomato.csv) and df_c (country-code.xlsx) based on common column Country Code

# %%
final_df=pd.merge(df,df_c,on='Country Code',how='left')

# %%
final_df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
#Data types of columns
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
#All the columns in final_df data set
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Number of unique values is each columns
final_df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
# Count of each countries in Country column
# index          #values
final_df['Country'].value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
# Storing the index of Country column in country_name_label
country_name_label=final_df['Country'].value_counts().index
country_name_label
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
# Storing the values of Country column in country_value
country_value=final_df['Country'].value_counts().values
country_value
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
#pie chart to display top 3 countries that uses Zomato
plt.pie(country_value[:3],labels=country_name_label[:3],autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x26f082708d0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.4%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.7%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.9%')])

# %%
#Observation from above pie chart
#1. Zomato maximum records or transactions are from India
# followed by United states and United Kingdom

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby('Country').agg({'Aggregate rating':'mean'}).sort_values(by='Aggregate rating',ascending=False)
# Out:
#                 Aggregate rating
# Country
# Phillipines             4.468182
# Turkey                  4.300000
# Indonesia               4.295238
# New Zealand             4.262500
# UAE                     4.233333
# South Africa            4.210000
# United Kingdom          4.087500
# Qatar                   4.060000
# United States           4.004378
# Sri Lanka               3.870000
# Brazil                  3.763333
# Australia               3.658333
# Canada                  3.575000
# Singapore               3.575000
# India                   2.523324

# %%
# The same thing can be done using below method/ beow code ie below 2 cell code
ratings=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating counts'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating counts
# 0                0.0        White   Not rated           2148
# 1                1.8          Red        Poor              1
# 2                1.9          Red        Poor              2
# 3                2.0          Red        Poor              7
# 4                2.1          Red        Poor             15
# 5                2.2          Red        Poor             27
# 6                2.3          Red        Poor             47
# 7                2.4          Red        Poor             87
# 8                2.5       Orange     Average            110
# 9                2.6       Orange     Average            191
# 10               2.7       Orange     Average            250
# 11               2.8       Orange     Average            315
# 12               2.9       Orange     Average            381
# 13               3.0       Orange     Average            468
# ...

# %%
## conclusion for above:
# When Rating is between 4.5 to 4.9 ------------> indicates excellent
# When Rating is between 4.0 to 4.4 ------------> indicated very Good
# When Rating is between 3.5 to 3.9 ------------> indicated Good

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=ratings,x='Aggregate rating',y='Rating counts')
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating counts'>

# %%
# The same thing can be done using above method/ beow code ie line no 137 and 134
rating=final_df.groupby('Aggregate rating').agg({'Aggregate rating':'count'}).rename(columns={'Aggregate rating':'Rating count'}).reset_index()
rating
# Out:
#     Aggregate rating  Rating count
# 0                0.0          2148
# 1                1.8             1
# 2                1.9             2
# 3                2.0             7
# 4                2.1            15
# 5                2.2            27
# 6                2.3            47
# 7                2.4            87
# 8                2.5           110
# 9                2.6           191
# 10               2.7           250
# 11               2.8           315
# 12               2.9           381
# 13               3.0           468
# 14               3.1           519
# 15               3.2           522
# 16               3.3           483
# 17               3.4           498
# 18               3.5           480
# 19               3.6           458
# 20               3.7           427
# 21               3.8           400
# 22               3.9           335
# 23               4.0           266
# 24               4.1           274
# 25               4.2           221
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=rating,x='Aggregate rating',y='Rating count')
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating count'>

# %%
# Observations:
# 1. Not rated count (i.e 0 is high)
# 2. Maximum number of rating are between 2.5 to 3.4

# %%
final_df.plot(kind='box',subplots=True,layout=(16,1),figsize=(10,60))
# Out:
# Restaurant ID           Axes(0.125,0.839474;0.775x0.0405263)
# Country Code            Axes(0.125,0.790842;0.775x0.0405263)
# Longitude               Axes(0.125,0.742211;0.775x0.0405263)
# Latitude                Axes(0.125,0.693579;0.775x0.0405263)
# Average Cost for two    Axes(0.125,0.644947;0.775x0.0405263)
# Price range             Axes(0.125,0.596316;0.775x0.0405263)
# Aggregate rating        Axes(0.125,0.547684;0.775x0.0405263)
# Votes                   Axes(0.125,0.499053;0.775x0.0405263)
# dtype: object

# %%
final_df['Votes'].value_counts()
# Out:
# Votes
# 0      1094
# 1       483
# 2       327
# 3       244
# 4       207
#        ...
# 615       1
# 538       1
# 823       1
# 650       1
# 901       1
# Name: count, Length: 1012, dtype: int64

# %%
# Question-1) Find the countries name that has given 0 ratings

#Solution:
#METHOD -1 (IN this method we cannot diplay the "Aggregate rating" column in final output)-->Disadvantage

# %%
# The same output can be obtained using below code(next cell) as well
zero_rating_countries=final_df[final_df['Aggregate rating']==0].groupby('Country').agg({'Aggregate rating':'count'}).reset_index().rename(columns={"Aggregate rating":'freq'})
zero_rating_countries.head()
# Out:
#           Country  freq
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
# Same code for above ..but another method
#METHOD -2 (IN this method we can diplay the "Aggregate rating" column in final output)-->Advantage
final_df[final_df['Aggregate rating']==0].groupby(["Country","Aggregate rating"]).size().reset_index().rename(columns={0:'FREQ'})
# Out:
#           Country  Aggregate rating  FREQ
# 0          Brazil               0.0     5
# 1           India               0.0  2139
# 2  United Kingdom               0.0     1
# 3   United States               0.0     3
