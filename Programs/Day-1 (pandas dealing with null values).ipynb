# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Prabal Kuinkel\Desktop\Data Analyst\PYTHON JUPYTERNOOTBOOK\Data sets and notes\Data sets\titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['PassengerId'].duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()   #Returns the count of null values is each columns
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#categorical columns
cat_col=[ c for c in df.columns if df[c].dtype=='object']
print('categorical columns:',cat_col)
#Numerical columns 
num_col = [c for c in df.columns if df[c].dtype!='object']
print('Numerical columns:',num_col)
# Out:
# categorical columns: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Numerical columns: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
df.nunique()  #Returns the number of unique elements
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Sex'].unique()  #Returns the unique elements in Sex column
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Name'].unique()[:5] #Returns the TOP 5 (0-4) unique elements in Name column
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry'], dtype=object)

# %%
# Handling the null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
round(df.isnull().sum()/df.shape[0]*100,2)  #calculate the percentage of null values in each column
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
df2 = df.drop(columns='Cabin')  #Drop the entire cabin column as it has 77% of null values and assign the new data frame to df2
df2 = df2.dropna(subset='Embarked',axis=0)  #1)dropna() removes the null values 2)Remove the null values of Embarked column 
                                            # 3)axis=0 (drops the rows containing the null values,by default axis is 0)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.hist(df2['Age'],bins=20,color='green',edgecolor='Black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)

# %%
print('min',df2['Age'].min())
print('max',df2['Age'].max())
# Out:
# min 0.42
# max 80.0

# %%
df3=df2.copy()

# %%
#Mean imputation ie filling the null values with mean
df3['Age'] = df2['Age'].fillna(df2['Age'].mean())

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.3+ KB

# %%
# to find the outlier of age column
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.boxplot(df3['Age'],vert=False)
plt.ylabel('Variable')
plt.xlabel('Age')
plt.title('Box Plot')
plt.show()

# %%
#Used normal distribution (look at the above histogram of age as there is high difference between ages)
#calculate summary statistics
mean = df3['Age'].mean()
std  = df3['Age'].std()
print('Mean :',mean)
print('std :',std)

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)
# Out:
# Mean : 29.642092696629216
# std : 12.968346294351784
# Lower Bound : 3.705400107925648
# Upper Bound : 55.578785285332785

# %%
df4=df3.copy()
df3.shape
# Out:
# (889, 11)

# %%
df4 = df3[(df3['Age']>=lower_bound) & (df3['Age']<=upper_bound)]
df4.shape
# Out:
# (821, 11)

# %%
df4.head(40)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# ...

# %%
plt.figure(figsize=(8,6))
plt.boxplot(df4['Age'],vert=False)
plt.grid(True)
plt.xlabel('Age')
plt.show()

# %%
df4.shape
# Out:
# (821, 11)

# %%
df4['Age'].mean()
# Out:
# 29.141474308530295

# %%
df4.describe()
# Out:
#        PassengerId   Survived      Pclass         Age       SibSp       Parch  \
# count   821.000000  821.00000  821.000000  821.000000  821.000000  821.000000
# mean    448.292326    0.37637    2.341048   29.141474    0.496955    0.349574
# std     257.354974    0.48477    0.825291   10.081243    1.082703    0.795316
# min       1.000000    0.00000    1.000000    4.000000    0.000000    0.000000
# 25%     226.000000    0.00000    2.000000   23.000000    0.000000    0.000000
# 50%     448.000000    0.00000    3.000000   29.642093    0.000000    0.000000
# 75%     672.000000    1.00000    3.000000   34.000000    1.000000    0.000000
# max     891.000000    1.00000    3.000000   55.500000    8.000000    6.000000
#
#              Fare
# count  821.000000
# mean    31.417590
# std     50.051174
# min      0.000000
# 25%      7.895800
# 50%     13.000000
# 75%     30.000000
# max    512.329200
